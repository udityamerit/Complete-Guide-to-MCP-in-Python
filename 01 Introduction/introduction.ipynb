# %% [markdown]
# # The Idea Behind MCP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # History of Agentinc AI Development / MCP

# %% [markdown]
# ![image.png](attachment:image.png)
